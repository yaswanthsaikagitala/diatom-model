# %%
import numpy as np
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import (
    confusion_matrix, classification_report,
    roc_curve, auc, precision_recall_curve,
    accuracy_score
)
from sklearn.utils.class_weight import compute_class_weight

# %%
# Load balanced training and test sets
X_train_res, y_train_res = joblib.load("X_train_balanced.pkl")
X_test, y_test           = joblib.load("X_test_balanced.pkl")
class_names              = joblib.load("class_names.pkl")   # species names

# %% [markdown]
# Train Logistic Regression with Class Weights

# %%
# Compute class weights
class_weights = compute_class_weight('balanced', classes=np.unique(y_train_res), y=y_train_res)
class_weight_dict = {i: w for i, w in enumerate(class_weights)}

# Train calibrated Logistic Regression
lr_model = CalibratedClassifierCV(
    LogisticRegression(C=5, solver='lbfgs', max_iter=10000,
                       class_weight=class_weight_dict, random_state=42),
    method='isotonic', cv=5
)
lr_model.fit(X_train_res, y_train_res)

# Save model
joblib.dump(lr_model, "logistic_regression.pkl")
print("✅ Logistic Regression model trained and saved as logistic_regression.pkl")
# Out:
# ✅ Logistic Regression model trained and saved as logistic_regression.pkl

# %% [markdown]
# Confusion Matrix

# %%
y_pred = lr_model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

# %% [markdown]
# Significance:
# Shows per-class performance and misclassifications

# %% [markdown]
# ROC Curve

# %%
y_prob = lr_model.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_prob[:,1], pos_label=1)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Logistic Regression")
plt.legend()
plt.show()

# %% [markdown]
# Significance:
# Evaluates sensitivity vs specificity

# %% [markdown]
# Precision-Recall Curve

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_prob[:,1], pos_label=1)

plt.figure(figsize=(8,6))
plt.plot(recall, precision, marker='.')
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve - Logistic Regression")
plt.show()

# %% [markdown]
# Significance:
# Useful for imbalanced datasets, showing trade-off between precision and recall

# %% [markdown]
# Confidence Frequency Distributio

# %%
plt.figure(figsize=(8,6))
sns.histplot(np.max(y_prob, axis=1), bins=20, kde=True, color="green")
plt.xlabel("Predicted Probability (Confidence)")
plt.ylabel("Frequency")
plt.title("Confidence Distribution - Logistic Regression")
plt.show()

# %% [markdown]
# Significance:
# Shows how confident the model is in its predictions

# %% [markdown]
# Class-wise Accuracy

# %%
report = classification_report(y_test, y_pred, target_names=class_names, output_dict=True)
class_acc = [report[cls]['recall'] for cls in class_names]

plt.figure(figsize=(10,6))
sns.barplot(x=class_names, y=class_acc, palette="viridis")
plt.xticks(rotation=45, ha="right")
plt.ylabel("Accuracy")
plt.title("Class-wise Accuracy - Logistic Regression")
plt.show()
# Out:
# C:\Users\Yaswanth\AppData\Local\Temp\ipykernel_11988\3290054321.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=class_acc, palette="viridis")

# %% [markdown]
# Significance:
# Highlights which species are classified well and which need improvement

# %% [markdown]
# Reliability Plot (Calibration Curve)

# %%
from sklearn.calibration import calibration_curve

y_prob = lr_model.predict_proba(X_test)

plt.figure(figsize=(10,8))
for i, cls in enumerate(class_names):
    # Binary labels: 1 if sample belongs to class i, else 0
    prob_true, prob_pred = calibration_curve(
        (y_test == i).astype(int),
        y_prob[:, i],
        n_bins=10
    )
    plt.plot(prob_pred, prob_true, marker='o', label=f"{cls}")

plt.plot([0,1],[0,1],'--',color='gray')
plt.xlabel("Mean Predicted Probability")
plt.ylabel("Fraction of Positives")
plt.title("Reliability Plot - Logistic Regression (per class)")
plt.legend()
plt.show()

# %%
import joblib
from sklearn.metrics import classification_report, accuracy_score

# Load model and supporting data
lr_model     = joblib.load("logistic_regression.pkl")
X_test, y_test = joblib.load("X_test_balanced.pkl")
class_names  = joblib.load("class_names.pkl")

# Predict on test set
y_pred = lr_model.predict(X_test)

# Overall accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Logistic Regression Accuracy: {accuracy:.4f}")

# Detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# Logistic Regression Accuracy: 0.7009
#
# Classification Report:
#                               precision    recall  f1-score   support
#
#         Achnanthidium jackii       0.54      0.68      0.60       575
#   Achnanthidium minutissimum       0.44      0.19      0.27       584
#            Amphora pediculus       0.65      0.62      0.63       620
#         Cocconeis placentula       0.77      0.90      0.83       365
# Discostella pseudostelligera       0.82      0.94      0.88       706
#            Navicula gregaria       0.73      0.87      0.79       465
#          Navicula lanceolata       0.93      0.89      0.91       455
#          Nitzschia dissipata       0.74      0.74      0.74       378
#         Nitzschia soratensis       0.56      0.56      0.56       411
#     Planothidium lanceolatum       0.73      0.69      0.71       389
#
#                     accuracy                           0.70      4948
#                    macro avg       0.69      0.71      0.69      4948
#                 weighted avg       0.69      0.70      0.68      4948

# %% [markdown]
# Significance:
# Shows how well predicted probabilities match actual outcomes.

# %% [markdown]
# ✅ Workflow Summary
# - Logistic Regression trained with isotonic calibration for reliable probabilities.
# - Evaluation suite: confusion matrix, ROC, PR curve, confidence distribution, class-wise accuracy, reliability plot.
# - Model saved as logistic_regression.pkl.
